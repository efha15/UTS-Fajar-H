# %%
def bs(arr, target):
    left,right = 0, len(arr)-1
    while left <= right :
        mid = left + (right-left)//2
        if arr[mid] == target: 
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

data = [1,3,7,5]
target = 3

result = bs(data,target)
if result == -1:
    print("not found")
else:
    print(f"found di indeks ke -  {result}")
